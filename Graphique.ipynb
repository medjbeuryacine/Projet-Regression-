# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Charger le fichier Excel
df = pd.read_csv("train.csv")  

# Tracer l'histogramme
plt.figure(figsize=(10,6))
sns.histplot(data=df, x="Price", hue="Transmission", kde=True, bins=30)

# Ajouter des labels
plt.xlabel("Prix")
plt.ylabel("Nombre de véhicules")
plt.title("Distribution des prix par type de transmission")

# Afficher le graphique
plt.show()

# %%
# Tracer l'histogramme
plt.figure(figsize=(10,6))
sns.histplot(data=df, x="Price", hue="Fuel_Type", kde=True, bins=30)

# Ajouter des labels
plt.xlabel("Prix")
plt.ylabel("Nombre de véhicules")
plt.title("Distribution des prix par type de Fuel")

# Afficher le graphique
plt.show()

# %%
# Tracer l'histogramme
plt.figure(figsize=(10,6))
sns.histplot(data=df, x="Price", hue="Location", kde=True, bins=30)

# Ajouter des labels
plt.xlabel("Prix")
plt.ylabel("Nombre de véhicules")
plt.title("Distribution des prix par Location")

# Afficher le graphique
plt.show()

# %%
# Tracer l'histogramme
plt.figure(figsize=(10,6))
sns.histplot(data=df, x="Price", hue="Year", kde=True, bins=30)

# Ajouter des labels
plt.xlabel("Prix")
plt.ylabel("Nombre de véhicules")
plt.title("Distribution des prix par Year")

# Afficher le graphique
plt.show()

# %%
# Tracer l'histogramme
plt.figure(figsize=(10,6))
sns.histplot(data=df, x="Price", hue="Owner_Type", kde=True, bins=30)

# Ajouter des labels
plt.xlabel("Prix")
plt.ylabel("Nombre de véhicules")
plt.title("Distribution des prix par Owner_type")

# Afficher le graphique
plt.show()

# %%
# Charger le fichier Excel
df_finale = pd.read_csv("data_finalle.csv")  

# Tracer l'histogramme
plt.figure(figsize=(10,6))
sns.histplot(data=df_finale, x="Price", hue="Transmission", kde=True, bins=30)

# Ajouter des labels
plt.xlabel("Prix")
plt.ylabel("Nombre de véhicules")
plt.title("Distribution des prix par type de transmission")

# Afficher le graphique
plt.show()

# %%
# Tracer l'histogramme
plt.figure(figsize=(10,6))
sns.histplot(data=df_finale, x="Price", hue="Fuel_Type", kde=True, bins=30)

# Ajouter des labels
plt.xlabel("Prix")
plt.ylabel("Nombre de véhicules")
plt.title("Distribution des prix par type de Fuel")

# Afficher le graphique
plt.show()

# %%
# Tracer l'histogramme
plt.figure(figsize=(10,6))
sns.histplot(data=df_finale, x="Price", hue="Location", kde=True, bins=30)

# Ajouter des labels
plt.xlabel("Prix")
plt.ylabel("Nombre de véhicules")
plt.title("Distribution des prix par Location")

# Afficher le graphique
plt.show()

# %%
# Tracer l'histogramme
plt.figure(figsize=(10,6))
sns.histplot(data=df_finale, x="Price", hue="Year", kde=True, bins=30)

# Ajouter des labels
plt.xlabel("Prix")
plt.ylabel("Nombre de véhicules")
plt.title("Distribution des prix par Year")

# Afficher le graphique
plt.show()

# %%
# Tracer l'histogramme
plt.figure(figsize=(10,6))
sns.histplot(data=df_finale, x="Price", hue="Owner_Type", kde=True, bins=30)

# Ajouter des labels
plt.xlabel("Prix")
plt.ylabel("Nombre de véhicules")
plt.title("Distribution des prix par Owner_type")

# Afficher le graphique
plt.show()
