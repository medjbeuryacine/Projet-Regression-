# %%
import pandas as pd

# %%
# ouverture du fichier cvs
data = pd.read_csv('data\\train.csv')
data
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %% [markdown]
# 6019 lignes et 13 colonnes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               6019 non-null   object
#  1   Location           6019 non-null   object
#  2   Year               6019 non-null   int64
#  3   Kilometers_Driven  6019 non-null   int64
#  4   Fuel_Type          6019 non-null   object
#  5   Transmission       6019 non-null   object
#  6   Owner_Type         6019 non-null   object
#  7   Mileage            6017 non-null   object
#  8   Engine             5983 non-null   object
#  9   Power              5983 non-null   object
#  10  Seats              5977 non-null   float64
#  11  New_Price          824 non-null    object
#  12  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 611.4+ KB

# %%
data.shape
# Out:
# (6019, 13)

# %% [markdown]
# - Colonne 'New_Price' a beaucoup de valeurs manquantes

# %%
# Vérification des doublons
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - pas de doublons dans les valeurs

# %%
# Colonne Name
print('Colonne Name : \n')
print('Doublons : ', data['Name'].duplicated().sum())

print('Name : ', data['Name'].value_counts(), '\n')
data['Name'].sort_values().unique().tolist()
# Out:
# Colonne Name :
#
# Doublons :  4143
# Name :  Name
# Mahindra XUV500 W8 2WD                        49
# Maruti Swift VDI                              45
# Honda City 1.5 S MT                           34
# Maruti Swift Dzire VDI                        34
# Maruti Swift VDI BSIV                         31
#                                               ..
# Hyundai i20 2015-2017 Magna                    1
# Tata Indica LEI                                1
# Mercedes-Benz GLA Class 200 Sport              1
# Skoda Rapid Ultima 1.6 TDI Elegance            1
# Mercedes-Benz New C-Class C 200 AVANTGARDE     1
# Name: count, Length: 1876, dtype: int64
# ['Ambassador Classic Nova Diesel',
#  'Audi A3 35 TDI Attraction',
#  'Audi A3 35 TDI Premium',
#  'Audi A3 35 TDI Premium Plus',
#  'Audi A3 35 TDI Technology',
#  'Audi A4 1.8 TFSI',
#  'Audi A4 1.8 TFSI Technology Edition',
#  'Audi A4 2.0 TDI',
#  'Audi A4 2.0 TDI 177 Bhp Premium Plus',
#  'Audi A4 2.0 TDI 177 Bhp Technology Edition',
# ...

# %%
# Colonne Year
print('Colonne Year : \n')
print('Doublons : ', data['Year'].duplicated().sum())

print('Années triées par nombre de fois d apparition : ', data['Year'].value_counts(), '\n')

print("min: ", data['Year'].min(),"\nmax: ",data['Year'].max())
# Out:
# Colonne Year :
#
# Doublons :  5997
# Années triées par nombre de fois d apparition :  Year
# 2014    797
# 2015    744
# 2016    741
# 2013    649
# 2017    587
# 2012    580
# 2011    466
# 2010    342
# 2018    298
# 2009    198
# 2008    174
# 2007    125
# 2019    102
# 2006     78
# 2005     57
# 2004     31
# 2003     17
# 2002     15
# 2001      8
# 2000      4
# 1998      4
# 1999      2
# Name: count, dtype: int64
#
# min:  1998
# max:  2019

# %% [markdown]
# - Les années sont comprises entre 1998 et 2019

# %%
# Colonne Localisation
print('Colonne Localisation : \n')
print('Doublons : ', data['Location'].duplicated().sum())

print('Type de carburant triés par nombre de fois d apparition : ', data['Location'].value_counts().sort_values(), '\n')
# Out:
# Colonne Localisation :
#
# Doublons :  6008
# Type de carburant triés par nombre de fois d apparition :  Location
# Ahmedabad     224
# Bangalore     358
# Jaipur        413
# Chennai       494
# Kolkata       535
# Delhi         554
# Pune          622
# Coimbatore    636
# Kochi         651
# Hyderabad     742
# Mumbai        790
# Name: count, dtype: int64

# %% [markdown]
# - type catégoriel : a voir les corrélations

# %%
# Colonne Type fuel
print('Colonne Fuel_Type : \n')
print('Doublons : ', data['Fuel_Type'].duplicated().sum())

print('Type de carburant triés par nombre de fois d apparition : ', data['Fuel_Type'].value_counts().sort_values(), '\n')
# Out:
# Colonne Fuel_Type :
#
# Doublons :  6014
# Type de carburant triés par nombre de fois d apparition :  Fuel_Type
# Electric       2
# LPG           10
# CNG           56
# Petrol      2746
# Diesel      3205
# Name: count, dtype: int64

# %% [markdown]
# - type catégoriel : 5 types différents de carburants (pour l'application on pourra faire une liste déroulante)

# %%
# Colonne Transmission
print('Colonne Transmission : \n')
print('Doublons : ', data['Transmission'].duplicated().sum())

print('Transmission triées par nombre de fois d apparition : ', data['Transmission'].value_counts().sort_values(), '\n')
# Out:
# Colonne Transmission :
#
# Doublons :  6017
# Transmission triées par nombre de fois d apparition :  Transmission
# Automatic    1720
# Manual       4299
# Name: count, dtype: int64

# %% [markdown]
# - type catégoriel : 2 types de transmissions possible

# %%
# Colonne Owner_Type
print('Colonne Owner_Type : \n')
print('Doublons : ', data['Owner_Type'].duplicated().sum())

print('Owner_Type triées par nombre de fois d apparition : ', data['Owner_Type'].value_counts().sort_values(), '\n')
# Out:
# Colonne Owner_Type :
#
# Doublons :  6015
# Owner_Type triées par nombre de fois d apparition :  Owner_Type
# Fourth & Above       9
# Third              113
# Second             968
# First             4929
# Name: count, dtype: int64

# %% [markdown]
# - type catégoriel : 4 catégories possibles

# %%
# Colonne Mileage
print('Colonne Mileage : \n')
print('Doublons : ', data['Mileage'].duplicated().sum())

data[['nb_mileage', 'type_mileage']] = data['Mileage'].str.rsplit(' ', n=1, expand=True)
data
# Out:
# Colonne Mileage :
#
# Doublons :  5576
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
data[['marque', 'modele']] = data['Name'].str.split(' ', n=1, expand=True)
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price nb_mileage type_mileage   marque  \
# ...

# %%
data[['nb_power', 'type_power']] = data['Power'].str.rsplit(' ', n=1, expand=True)
data['type_power'].value_counts()
# Out:
# type_power
# bhp    5983
# Name: count, dtype: int64

# %% [markdown]
# - il n'y a qu'un seul type de puissance donc nous n'avons pas besoin de ces 2 nouvelles colonnes

# %%
data.drop(['nb_power', 'type_power'], axis=1, inplace=True)
data.head()
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
data[['nb_engine', 'type_engine']] = data['Engine'].str.rsplit(' ', n=1, expand=True)
data['type_engine'].value_counts()
# Out:
# type_engine
# CC    5983
# Name: count, dtype: int64

# %% [markdown]
# - il n'y a qu'un seul type de engine donc nous n'avons pas besoin de ces 2 nouvelles colonnes

# %%
data.drop(['nb_engine', 'type_engine'], axis=1, inplace=True)
data.head()
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
data['marque'].str.upper().value_counts().sort_values()
# Out:
# marque
# SMART               1
# AMBASSADOR          1
# LAMBORGHINI         1
# BENTLEY             1
# FORCE               3
# ISUZU               3
# DATSUN             13
# JEEP               15
# PORSCHE            18
# VOLVO              21
# MINI               26
# MITSUBISHI         27
# FIAT               28
# JAGUAR             40
# LAND               60
# NISSAN             91
# CHEVROLET         121
# RENAULT           145
# SKODA             173
# TATA              186
# AUDI              236
# BMW               267
# MAHINDRA          272
# FORD              300
# VOLKSWAGEN        315
# MERCEDES-BENZ     318
# TOYOTA            411
# HONDA             608
# HYUNDAI          1107
# MARUTI           1211
# Name: count, dtype: int64

# %%
data['modele'].str.upper().sort_values().value_counts()
# Out:
# modele
# SWIFT DZIRE VDI      50
# XUV500 W8 2WD        49
# SWIFT VDI            45
# CITY 1.5 S MT        34
# SWIFT VDI BSIV       31
#                      ..
# XYLO D2 BSIV          1
# XYLO D2 MAXX          1
# XYLO D4 BSIV          1
# XUV300 W8 DIESEL      1
# XUV500 AT W10 AWD     1
# Name: count, Length: 1852, dtype: int64

# %%
data['modele'].value_counts()
# Out:
# modele
# XUV500 W8 2WD                   49
# Swift VDI                       45
# Swift Dzire VDI                 34
# City 1.5 S MT                   34
# Swift VDI BSIV                  31
#                                 ..
# New Safari EX 4x2                1
# Terrano XL Plus ICC WT20 SE      1
# Brio 1.2 S Option MT             1
# Vento Konekt Diesel Highline     1
# Gallardo Coupe                   1
# Name: count, Length: 1876, dtype: int64

# %% [markdown]
# - on réfléchi à l'encodage qui peut être compliqué sur le nombre de modèles différents... à réfléchir si on garde la colonne ou pas

# %%
data.groupby('Fuel_Type')['type_mileage'].value_counts()
# Out:
# Fuel_Type  type_mileage
# CNG        km/kg             56
# Diesel     kmpl            3205
# LPG        km/kg             10
# Petrol     kmpl            2746
# Name: count, dtype: int64

# %% [markdown]
# - le type de mileage dépend du type de carburant, si c'est un carburant gaz = km/kg, si c'est un carburant de type 'essence' alors c'est en kmpl

# %%
data[data['Fuel_Type'] == 'Electric']
# Out:
#                            Name Location  Year  Kilometers_Driven Fuel_Type  \
# 4446       Mahindra E Verito D4  Chennai  2016              50000  Electric
# 4904  Toyota Prius 2009-2016 Z4   Mumbai  2011              44000  Electric
#
#      Transmission Owner_Type Mileage   Engine   Power  Seats   New_Price  \
# 4446    Automatic      First     NaN    72 CC  41 bhp    5.0  13.58 Lakh
# 4904    Automatic      First     NaN  1798 CC  73 bhp    5.0         NaN
#
#       Price nb_mileage type_mileage    marque              modele
# 4446  13.00        NaN          NaN  Mahindra         E Verito D4
# 4904  12.75        NaN          NaN    Toyota  Prius 2009-2016 Z4

# %% [markdown]
# - il n'y a que 2 lignes pour l'entrainement sur le type de type_fuel = 'electric' alors nous avons pris la décison de supprimer ces lignes car elles se seront pas assez représentative pour le modèle

# %%
dftest = pd.read_csv('test.csv')
dftest[dftest['Fuel_Type'] == 'Electric']
# Out:
# Empty DataFrame
# Columns: [Name, Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, New_Price]
# Index: []

# %% [markdown]
# - il n'y a pas de lignes de test de véhicule de type electric. Ce qui nous conforte dans notre choix.

# %%
data.drop(['Name', 'New_Price', 'Mileage', 'type_mileage'], axis=1, inplace=True)
data
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual      First
# 1           Pune  2015              41000    Diesel       Manual      First
# 2        Chennai  2011              46000    Petrol       Manual      First
# 3        Chennai  2012              87000    Diesel       Manual      First
# 4     Coimbatore  2013              40670    Diesel    Automatic     Second
# ...          ...   ...                ...       ...          ...        ...
# 6014       Delhi  2014              27365    Diesel       Manual      First
# 6015      Jaipur  2015             100000    Diesel       Manual      First
# 6016      Jaipur  2012              55000    Diesel       Manual     Second
# 6017     Kolkata  2013              46000    Petrol       Manual      First
# 6018   Hyderabad  2011              47000    Diesel       Manual      First
#
# ...

# %% [markdown]
# - On supprime les colonnes qui ne nous servent plus

# %% [markdown]
# - OrdinalEncoder !

# %%
data['Engine'] = data['Engine'].str.replace("CC", "")
data['Power'] = data['Power'].str.replace("bhp", "")
data.head()
# Out:
#         Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         Mumbai  2010              72000       CNG       Manual      First
# 1           Pune  2015              41000    Diesel       Manual      First
# 2        Chennai  2011              46000    Petrol       Manual      First
# 3        Chennai  2012              87000    Diesel       Manual      First
# 4     Coimbatore  2013              40670    Diesel    Automatic     Second
# ...          ...   ...                ...       ...          ...        ...
# 6014       Delhi  2014              27365    Diesel       Manual      First
# 6015      Jaipur  2015             100000    Diesel       Manual      First
# 6016      Jaipur  2012              55000    Diesel       Manual     Second
# 6017     Kolkata  2013              46000    Petrol       Manual      First
# 6018   Hyderabad  2011              47000    Diesel       Manual      First
#
# ...

# %% [markdown]
# - on a supprimé le texte des colonnes Engine et Power pour ne garder que les données numériques

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Location           6019 non-null   object
#  1   Year               6019 non-null   int64
#  2   Kilometers_Driven  6019 non-null   int64
#  3   Fuel_Type          6019 non-null   object
#  4   Transmission       6019 non-null   object
#  5   Owner_Type         6019 non-null   object
#  6   Engine             5983 non-null   object
#  7   Power              5983 non-null   object
#  8   Seats              5977 non-null   float64
#  9   Price              6019 non-null   float64
#  10  nb_mileage         6017 non-null   object
#  11  marque             6019 non-null   object
#  12  modele             6019 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 611.4+ KB
