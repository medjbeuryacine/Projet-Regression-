# %% [markdown]
# # remplacer les NaN par la moyenne

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# ...

# %%
echange = 0.011
def prix_euro(price):
    return price * 100000 * echange
data["prix_euro"] = data["Price"].map(prix_euro)

# %%
data['marque_modele'] = data['Name'].str.split(' ', n=2, expand=True).iloc[:, :2].agg(' '.join, axis=1)

# %%
data.drop(["Name","Price","New_Price","Location"], axis=1, inplace=True)
data.head()
# Out:
#    Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0  2010              72000       CNG       Manual      First  26.6 km/kg
# 1  2015              41000    Diesel       Manual      First  19.67 kmpl
# 2  2011              46000    Petrol       Manual      First   18.2 kmpl
# 3  2012              87000    Diesel       Manual      First  20.77 kmpl
# 4  2013              40670    Diesel    Automatic     Second   15.2 kmpl
#
#     Engine      Power  Seats  prix_euro  marque_modele
# 0   998 CC  58.16 bhp    5.0     1925.0   Maruti Wagon
# 1  1582 CC  126.2 bhp    5.0    13750.0  Hyundai Creta
# 2  1199 CC   88.7 bhp    5.0     4950.0     Honda Jazz
# 3  1248 CC  88.76 bhp    7.0     6600.0  Maruti Ertiga
# 4  1968 CC  140.8 bhp    5.0    19514.0        Audi A4

# %%
# convertir str => float
data['Engine'] = data['Engine'].str.replace("CC", "").astype(float, errors='ignore')
data['Power'] = pd.to_numeric(data['Power'].str.replace("bhp", ""), errors="coerce")
data["Mileage"] = data["Mileage"].str.replace("km/kg", "")
data["Mileage"] = data["Mileage"].str.replace("kmpl", "").astype(float, errors='ignore')

# %%
data[data["Fuel_Type"] == "Electric"]
# Out:
# Empty DataFrame
# Columns: [Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, prix_euro, marque_modele]
# Index: []

# %%
# supprimer les deux ligne de Fuel_Type = Electric parceque on a juste deux lignes
data.drop([4446,4904], axis=0, inplace=True)

# %%
data[data.isna().any(axis=1)].groupby("marque_modele").size()
# Out:
# marque_modele
# Audi A4                   1
# BMW 5                     5
# Chevrolet Optra           1
# Fiat Petra                1
# Fiat Punto                3
# Fiat Siena                1
# Ford Endeavour            2
# Ford Fiesta               3
# Ford Figo                 1
# Honda CR-V                2
# Honda City                5
# Honda Jazz                1
# Hyundai Santro           49
# Land Rover                3
# Mahindra Bolero           1
# Mahindra Jeep             2
# Maruti 1000               1
# Maruti Baleno             2
# Maruti Esteem             3
# Maruti Estilo             3
# Maruti Swift             26
# Maruti Wagon              1
# Mercedes-Benz E-Class     2
# Nissan Micra              1
# Nissan Teana              1
# Porsche Cayman            2
# Skoda Laura               1
# Smart Fortwo              1
# Tata Indica               3
# Toyota Etios             14
# Toyota Qualis             2
# Volkswagen Jetta          1
# dtype: int64

# %%
data.isna().sum() # les valeur manquente
# Out:
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage                0
# Engine                36
# Power                143
# Seats                 42
# prix_euro              0
# marque_modele          0
# dtype: int64

# %%
# remplacer NaN par la moyenne => fini
data[data["Engine"].isna()].groupby("marque_modele").size()
# Out:
# Series([], dtype: int64)

# %%
data.loc[data["Engine"].isna(), "Engine"] = np.round(np.mean((data["Engine"])))

# %%
# remplacer NaN par la moyenne => fini
data[data["Power"].isna()].groupby("marque_modele").size()
# Out:
# Series([], dtype: int64)

# %%
data.loc[data["Power"].isna(), "Power"] = np.round(np.mean((data["Power"])))

# %%
# remplacer NaN par la moyenne => fini
data[data["Seats"].isna()].groupby("marque_modele").size()
# Out:
# Series([], dtype: int64)

# %%
data.loc[data["Seats"].isna(), "Seats"] = np.round(np.mean((data["Seats"])))

# %%
data.isna().sum() # pas de valeur manquente
# Out:
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# prix_euro            0
# marque_modele        0
# dtype: int64

# %%
for col in data.columns:
    plt.figure(figsize=(15,10))
    sns.boxplot(data[col])

# %%
from sklearn.cluster import DBSCAN
import numpy as np

for col in data.select_dtypes(np.number).columns:
    X = data[col].values.reshape(-1, 1)
    db = DBSCAN(eps=30000, min_samples=2).fit(X) 
    data["valeur_aburante"] = db.labels_
    plt.figure(figsize=(15,10))
    plt.title(col)
    plt.scatter(data[col], [0] * len(data), c=data["valeur_aburante"], cmap="viridis", marker="o")
    plt.colorbar(label="Cluster (-1 = anomalie)")
    plt.show()

# %%
X = data["Kilometers_Driven"].values.reshape(-1, 1)
db = DBSCAN(eps=30000, min_samples=2).fit(X) 
data["valeur_aburante"] = db.labels_

# %%
data[data["valeur_aburante"] == -1]
# Out:
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  \
# 340   2013             775000    Diesel    Automatic      First    19.30
# 358   2009             620000    Petrol       Manual      First    20.36
# 1860  2013             720000    Diesel       Manual      First    20.54
# 2328  2017            6500000    Diesel    Automatic      First    15.97
# 4491  2013             445000    Petrol       Manual      First    18.50
#
#       Engine  Power  Seats  prix_euro     marque_modele  valeur_aburante
# 340   1968.0  141.0    5.0     8250.0     Skoda Octavia               -1
# 358   1197.0   78.9    5.0     2970.0       Hyundai i10               -1
# 1860  1598.0  103.6    5.0     6490.0  Volkswagen Vento               -1
# 2328  2993.0  258.0    5.0    71500.0            BMW X5               -1
# 4491  1197.0   82.9    5.0     4895.0       Hyundai i20               -1

# %%
data[data["prix_euro"] == data["prix_euro"].max()]
# Out:
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  \
# 4079  2017              25000    Diesel    Automatic      First    13.33
#
#       Engine  Power  Seats  prix_euro marque_modele  valeur_aburante
# 4079  2993.0  255.0    5.0   176000.0    Land Rover                0

# %%
# drop les valeur aburante dans la colonne "Kilometers_Driven"
data.drop([340,358,1860,2328,4491,4079], axis=0, inplace=True)

# %%
data.drop("valeur_aburante", axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6011 entries, 0 to 6018
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               6011 non-null   int64
#  1   Kilometers_Driven  6011 non-null   int64
#  2   Fuel_Type          6011 non-null   object
#  3   Transmission       6011 non-null   object
#  4   Owner_Type         6011 non-null   object
#  5   Mileage            6011 non-null   float64
#  6   Engine             6011 non-null   float64
#  7   Power              6011 non-null   float64
#  8   Seats              6011 non-null   float64
#  9   prix_euro          6011 non-null   float64
#  10  marque_modele      6011 non-null   object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 563.5+ KB

# %%
data.to_csv("data_nan_remplit_main.csv", index=False)
